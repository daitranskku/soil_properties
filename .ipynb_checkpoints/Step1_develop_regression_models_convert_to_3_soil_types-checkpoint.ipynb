# %% [markdown]
# # **Develop Regression Models for Soil Properties Estimation**

# %%
from tensorflow.python.client import device_lib
print("GPU sample processing: ")
print(device_lib.list_local_devices())
# Out:
# GPU sample processing:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 2269041350361442101
# ]

# %%
import os

import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from tqdm import tqdm

from sklearn import preprocessing
import tensorflow as tf
import tensorflow_probability as tfp

# %% [markdown]
# ### Load data

# %%
DATA_DIR = '/home/daitran/Desktop/git/soil_properties/data'

ntb_data_path = os.path.join(DATA_DIR, 'NTB_black_data_remove_class_5.csv')
tb_data_path = os.path.join(DATA_DIR, '210507 TB (Blue) data_(PDF and CAD).csv')

ntb_data= pd.read_csv(ntb_data_path)
tb_data = pd.read_csv(tb_data_path)

# %% [markdown]
# ### Data pre-processing

# %%
# Specific soil types
# Convert to 3 soil types only!
assign_num_list = {
                    'topsoil layer': 2,
                    'reclaimed layer': 2,
                    'sedimentary layer': 2,
                    'weathered soil': 2,
                    'weathered rock': 1,
                    'soft rock': 0,
                    'moderate rock': 0,
                     'hard rock': 0,
                  }

# %%
ntb_names = ntb_data['Soi properties (main)']
tb_names = tb_data['Soi properties (main)']

ntb_target = ntb_names.replace(assign_num_list)
tb_target = tb_names.replace(assign_num_list)

ntb_data['Target'] = ntb_target
tb_data['Target'] = tb_target

X_train_ntb = ntb_data[['X','Y','Elevation']].to_numpy()
y_train_ntb = ntb_data['Target'].to_numpy()

X_train_tb = tb_data[['X1(CAD)','Y1(CAD)','Elevation']].to_numpy()
y_train_tb = tb_data['Target'].to_numpy()

# https://scikit-learn.org/stable/modules/preprocessing.html
normalizer = preprocessing.MinMaxScaler()

normalized_X_train_ntb = normalizer.fit_transform(X_train_ntb)
normalized_X_train_tb = normalizer.fit_transform(X_train_tb)

# merge NTB and TB
X_train_merged_ntb_tb = np.concatenate((X_train_ntb, X_train_tb), axis=0)
normalized_X_merged_ntb_tb = np.concatenate((normalized_X_train_ntb, normalized_X_train_tb), axis=0)
y_train_merged_ntb_tb = np.concatenate((y_train_ntb, y_train_tb), axis=0)

# %%
ntb_data
# Out:
#       Name          X          Y  Elevation Soi properties (main)  Unnamed: 5  \
# 0    NTB-1  549723.89  213802.88      128.5       reclaimed layer         NaN
# 1    NTB-1  549723.89  213802.88      126.0     sedimentary layer         NaN
# 2    NTB-1  549723.89  213802.88      121.5        weathered soil         NaN
# 3    NTB-1  549723.89  213802.88      107.7        weathered rock         NaN
# 4    NTB-1  549723.89  213802.88       99.7             soft rock         NaN
# ..     ...        ...        ...        ...                   ...         ...
# 90  NTB-12  549564.60  213804.70      114.5        weathered rock         NaN
# 91  NTB-12  549564.60  213804.70      107.5         moderate rock         NaN
# 92  NTB-12  549564.60  213804.70       89.5             hard rock         NaN
# 93  NTB-12  549564.60  213804.70       86.5         moderate rock         NaN
# 94  NTB-12  549564.60  213804.70       83.5             hard rock         NaN
#
#     Update evlevation  Elevation past  Target
# 0               128.5            28.5       2
# 1               126.0            26.0       2
# 2               121.5            21.5       2
# 3               107.7             7.7       1
# 4                99.7            -0.3       0
# ..                ...             ...     ...
# 90              114.5            14.5       1
# 91              107.5             7.5       0
# 92               89.5           -10.5       0
# 93               86.5           -13.5       0
# 94               83.5           -16.5       0
#
# [95 rows x 9 columns]

# %%
tb_data
# Out:
#       Name            X            Y  Elevation Soi properties (main)  \
# 0     TB-1  549699.0411  213765.3279     128.60       reclaimed layer
# 1     TB-1  549699.0411  213765.3279     126.60     sedimentary layer
# 2     TB-1  549699.0411  213765.3279     117.60        weathered soil
# 3     TB-1  549699.0411  213765.3279     108.10        weathered rock
# 4     TB-1  549699.0411  213765.3279      94.60             soft rock
# ..     ...          ...          ...        ...                   ...
# 111  TB-22  550622.5600  213730.7000     134.49       reclaimed layer
# 112  TB-22  550622.5600  213730.7000     114.19        weathered soil
# 113  TB-22  550622.5600  213730.7000     104.19        weathered rock
# 114  TB-22  550622.5600  213730.7000      93.69             soft rock
# 115  TB-22  550622.5600  213730.7000      86.99             hard rock
#
#      Unnamed: 5  Unnamed: 6      X1(CAD)      Y1(CAD)  Target
# 0           NaN         NaN  549699.0411  213765.3279       2
# 1           NaN         NaN  549699.0411  213765.3279       2
# 2           NaN         NaN  549699.0411  213765.3279       2
# 3           NaN         NaN  549699.0411  213765.3279       1
# 4           NaN         NaN  549699.0411  213765.3279       0
# ..          ...         ...          ...          ...     ...
# 111         NaN         NaN  550626.9000  213737.3069       2
# 112         NaN         NaN  550626.9000  213737.3069       2
# 113         NaN         NaN  550626.9000  213737.3069       1
# 114         NaN         NaN  550626.9000  213737.3069       0
# 115         NaN         NaN  550626.9000  213737.3069       0
#
# [116 rows x 10 columns]

# %% [markdown]
# # Deterministic Models

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import RMSprop

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# ### Deep regression neural network

# %%
def create_model(dim):
    model = Sequential([
        Dense(64, activation = 'relu', kernel_initializer='he_normal', input_dim = dim),
        Dense(32, activation = 'relu', kernel_initializer='he_normal'),
        Dense(16, activation = 'relu', kernel_initializer='he_normal'),
        Dense(8, activation = 'relu', kernel_initializer='he_normal'),
        Dense(1, kernel_initializer='he_normal', activation='linear')
    ])
    
    model.compile(loss='mean_squared_error',
              optimizer=tf.optimizers.Adam(learning_rate=0.001))
    
    model.summary()
    return model

# %% [markdown]
# ### Customized callbacks

# %%
def get_checkpoint_best_only(model_type = 'deterministic', train_data = 'ntb'):
    current_dir = os.getcwd()
    if model_type:
        checkpoint_path = current_dir + "/checkpoints_best_only_{}_{}/checkpoint".format(model_type, train_data)

    checkpoint = ModelCheckpoint(filepath = checkpoint_path,
                                frequency = "epoch",
                                save_weights_only = True,
                                monitor = "mean_squared_error",
                                save_best_ony = True,
                                verbose = 1)
    return checkpoint

# %%
def get_early_stopping():
    early_stopping = EarlyStopping(monitor = "loss", mode ="min", patience = 5)
    return early_stopping

# %%
checkpoint_best_only = get_checkpoint_best_only(model_type = 'deterministic', train_data = 'ntb')
early_stopping = get_early_stopping()

# %%
callbacks = [checkpoint_best_only, early_stopping]

# %%
model = create_model(dim = 3)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 3,009
# Trainable params: 3,009
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Train on NTB**

# %%
# %%time
hist = model.fit(normalized_X_train_ntb, y_train_ntb, 
                epochs = 500, verbose=1,
                batch_size=16,
                callbacks=callbacks)
#                 validation_data=(normalized_X_train_tb,y_train_tb))
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 3ms/step - loss: 1.3051
#
# Epoch 00001: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch
saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 35/500
# 6/6 [==============================] - 0s 1ms/step - loss: 0.1331
#
# Epoch 00035: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 36/500
# 6/6 [==============================] - 0s 906us/step - loss: 0.1234
#
# Epoch 00036: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 37/500
# 6/6 [==============================] - 0s 925us/step - loss: 0.1586
#
# Epoch 00037: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 38/500
# 6/6 [==============================] - 0s 857us/step - loss: 0.1332
#
# Epoch 00038: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 39/500
# 6/6 [==============================] - 0s 884us/step - loss: 0.1109
#
# Epoch 00039: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 40/500
# 6/6 [==============================] - 0s 693us/step - loss: 0.1386
#
# Epoch 00040: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 41/500
# 6/6 [==============================] - 0s 746us/step - loss: 0.1426
#
# Epoch 00041: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 42/500
# 6/6 [==============================] - 0s 743us/step - loss: 0.1151
#
# Epoch 00042: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 43/500
# 6/6 [==============================] - 0s 905us/step - loss: 0.1316
#
# Epoch 00043: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 44/500
# 6/6 [==============================] - 0s 841us/step - loss: 0.1081
#
# Epoch 00044: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 45/500
# 6/6 [==============================] - 0s 901us/step - loss: 0.1204
#
# Epoch 00045: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 46/500
# 6/6 [==============================] - 0s 806us/step - loss: 0.1500
#
# Epoch 00046: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 47/500
# 6/6 [==============================] - 0s 798us/step - loss: 0.1335
#
# Epoch 00047: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 48/500
# 6/6 [==============================] - 0s 983us/step - loss: 0.1480
#
# Epoch 00048: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 49/500
# 6/6 [==============================] - 0s 695us/step - loss: 0.1329
#
# Epoch 00049: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 50/500
# 6/6 [==============================] - 0s 715us/step - loss: 0.1187
#
# Epoch 00050: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 51/500
# 6/6 [==============================] - 0s 893us/step - loss: 0.1414
#
# Epoch 00051: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# Epoch 52/500
# 6/6 [==============================] - 0s 852us/step - loss: 0.1795
#
# Epoch 00052: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_ntb/checkpoint
# CPU times: user 1.46 s, sys: 105 ms, total: 1.56 s
# Wall time: 2.11 s

# %%
plt.plot(hist.history['loss'],'r',label='loss')
# plt.plot(hist.history['val_loss'],'b',label='val_loss')
plt.title('Training loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# ### **Train on TB**

# %%
model = create_model(dim = 3)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 3,009
# Trainable params: 3,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_best_only = get_checkpoint_best_only(model_type = 'deterministic', train_data = 'tb')
early_stopping = get_early_stopping()
callbacks = [checkpoint_best_only, early_stopping]

# %%
# %%time
hist = model.fit(normalized_X_train_tb, y_train_tb, 
                epochs = 500, verbose=1,
                batch_size=16,
                callbacks=callbacks)
#                 validation_data=(normalized_X_train_tb,y_train_tb))
# Out:
# Epoch 1/500
# 8/8 [==============================] - 0s 832us/step - loss: 0.7835
#
# Epoch 00001: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 2/500
# 8/8 [==============================] - 0s 680us/step - loss: 0.5334
#
# Epoch 00002: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 3/500
# 8/8 [==============================] - 0s 672us/step - loss: 0.3948
#
# Epoch 00003: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 4/500
# 8/8 [==============================] - 0s 787us/step - loss: 0.2825
#
# Epoch 00004: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 5/500
# 8/8 [==============================] - 0s 769us/step - loss: 0.1810
#
# Epoch 00005: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 6/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1709
#
# Epoch 00006: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 7/500
# 8/8 [==============================] - 0s 886us/step - loss: 0.1429
#
# Epoch 00007: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 8/500
# 8/8 [==============================] - 0s 899us/step - loss: 0.1053
#
# Epoch 00008: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 9/500
# 8/8 [==============================] - 0s 812us/step - loss: 0.1228
#
# Epoch 00009: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 10/500
# 8/8 [==============================] - 0s 714us/step - loss: 0.1238
#
# Epoch 00010: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 11/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.1347
#
# Epoch 00011: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 12/500
# 8/8 [==============================] - 0s 668us/step - loss: 0.1738
#
# Epoch 00012: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 13/500
# 8/8 [==============================] - 0s 692us/step - loss: 0.1195
#
# Epoch 00013: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 14/500
# 8/8 [==============================] - 0s 815us/step - loss: 0.1182
#
# Epoch 00014: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 15/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1386
#
# Epoch 00015: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 16/500
# 8/8 [==============================] - 0s 687us/step - loss: 0.1171
#
# Epoch 00016: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 17/500
# 8/8 [==============================] - 0s 869us/step - loss: 0.1399
#
# Epoch 00017: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 18/500
# 8/8 [==============================] - 0s 904us/step - loss: 0.1268
#
# Epoch 00018: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 19/500
# 8/8 [==============================] - 0s 617us/step - loss: 0.1126
#
# Epoch 00019: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# Epoch 20/500
# 8/8 [==============================] - 0s 801us/step - loss: 0.1231
#
# Epoch 00020: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_tb/checkpoint
# CPU times: user 740 ms, sys: 56.8 ms, total: 797 ms
# Wall time: 655 ms

# %%
plt.plot(hist.history['loss'],'r',label='loss')
# plt.plot(hist.history['val_loss'],'b',label='val_loss')
plt.title('Training loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# ### **Train on merged NTB and TB**

# %%
model = create_model(dim = 3)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 64)                256
# _________________________________________________________________
# dense_11 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 136
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 3,009
# Trainable params: 3,009
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_best_only = get_checkpoint_best_only(model_type = 'deterministic', train_data = 'merged_ntb_tb')
early_stopping = get_early_stopping()
callbacks = [checkpoint_best_only, early_stopping]

# %%
# %%time
hist = model.fit(normalized_X_merged_ntb_tb, y_train_merged_ntb_tb, 
                epochs = 500, verbose=1,
                batch_size=16,
                callbacks=callbacks)
#                 validation_data=(normalized_X_train_tb,y_train_tb))
# Out:
# Epoch 1/500
# 14/14 [==============================] - 0s 648us/step - loss: 0.6543
#
# Epoch 00001: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 2/500
# 14/14 [==============================] - 0s 673us/step - loss: 0.3550
#
# Epoch 00002: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 3/500
# 14/14 [==============================] - 0s 679us/step - loss: 0.3831
#
# Epoch 00003: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 4/500
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3022
#
# Epoch 00004: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 5/500
# 14/14 [==============================] - 0s 864us/step - loss: 0.2425
#
# Epoch 00005: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 6/500
# 14/14 [==============================] - 0s 658us/step - loss: 0.3097
#
# Epoch 00006: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 7/500
# 14/14 [==============================] - 0s 612us/step - loss: 0.2495
#
# Epoch 00007: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 8/500
# 14/14 [==============================] - 0s 786us/step - loss: 0.2527
#
# Epoch 00008: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 9/500
# 14/14 [==============================] - 0s 585us/step - loss: 0.2242
#
# Epoch 00009: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 10/500
# 14/14 [==============================] - 0s 739us/step - loss: 0.2017
#
# Epoch 00010: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 11/500
# 14/14 [==============================] - 0s 666us/step - loss: 0.2532
#
# Epoch 00011: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 12/500
# 14/14 [==============================] - 0s 685us/step - loss: 0.2024
#
# Epoch 00012: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 13/500
# 14/14 [==============================] - 0s 796us/step - loss: 0.1997
#
# Epoch 00013: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 14/500
# 14/14 [==============================] - 0s 677us/step - loss: 0.1720
#
# Epoch 00014: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 15/500
# 14/14 [==============================] - 0s 624us/step - loss: 0.1892
#
# Epoch 00015: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch
saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 49/500
# 14/14 [==============================] - 0s 714us/step - loss: 0.1654
#
# Epoch 00049: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 50/500
# 14/14 [==============================] - 0s 676us/step - loss: 0.1503
#
# Epoch 00050: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# Epoch 51/500
# 14/14 [==============================] - 0s 645us/step - loss: 0.1036
#
# Epoch 00051: saving model to /home/daitran/Desktop/git/soil_properties/checkpoints_best_only_deterministic_merged_ntb_tb/checkpoint
# CPU times: user 1.88 s, sys: 164 ms, total: 2.04 s
# Wall time: 1.59 s

# %%
plt.plot(hist.history['loss'],'r',label='loss')
# plt.plot(hist.history['val_loss'],'b',label='val_loss')
plt.title('Training loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %% [markdown]
# # Probabilistic models

# %% [markdown]
# In the deterministic models, we develop ANN's weights with a single value. However, the true value of this weight is not certion. Because we have too little data points, therefor the training data contains its uncertainty. So, we have to develop the model that can handle the uncertainty in deep learning models. This is done by changing each weight from a single deterministic value to a probability distribution.

# %% [markdown]
# ### Baysian Neural Network

# %%
# tfd = tfp.distributions
# tfpl = tfp.layers

# %%
# def prior(kernel_size, bias_size, dtype = None):
#     n = kernel_size + bias_size
#     prior_model = Sequential([
#         tfpl.DistributionLambda(
#             lambda t : tfd.MultivariateNormalDiag(loc = tf.zeros(n), scale_diag = tf.ones(n))
#         )
#     ])
#     return prior_model

# %%
# def posterior(kernel_size, bias_size, dtype = None):
#     n = kernel_size + bias_size
#     posterior_model = Sequential([
#         tfpl.VariableLayer(tfpl.MultivariateNormalTriL.params_size(n), dtype = dtype),
#         tfpl.MultivariateNormalTriL(n)
#     ])
#     return posterior_model

# %%
# model_prob = Sequential([
#     tfpl.DenseVariational(units=20,
#                           input_shape=(3,),
#                           make_prior_fn=prior,
#                           make_posterior_fn=posterior,
#                           kl_weight=1/normalized_X_train_ntb.shape[0],
#                           activation='relu'),
#     tfpl.DenseVariational(units=tfpl.IndependentNormal.params_size(1),
#                           make_prior_fn=prior,
#                           make_posterior_fn=posterior,
#                           kl_weight=1/normalized_X_train_ntb.shape[0]),
#     tfpl.IndependentNormal(1)
# ])

# %%
# def nll(y_true, y_pred):
#     return -y_pred.log_prob(y_true)

# model_prob.compile(loss=nll, optimizer=tf.optimizers.Adam(learning_rate=0.001))
# model_prob.summary()

# %%
# normalized_X_train_ntb_d =  tf.constant(normalized_X_train_ntb, dtype=tf.float64)

# %%
# tf.dtypes.cast(normalized_X_train_ntb_d, tf.float64)

# %%
# y_train_ntb_d =  tf.constant(y_train_ntb, dtype=tf.float64)

# %%
# tf.dtypes.cast(y_train_ntb_d, tf.float64)

# %%
# tf.config.run_functions_eagerly(True)

# %%
# checkpoint_best_only = get_checkpoint_best_only(model_type = 'probabilistic')
# callbacks_prob = [checkpoint_best_only]

# %% [markdown]
# ### Train

# %%
# his_prob = model_prob.fit(normalized_X_train_ntb_d, y_train_ntb_d,
#                      epochs=100, verbose=1,
# #                      batch_size = 10,
#                      callbacks=callbacks_prob
#                          )

# %%
# plt.plot(his_prob.history['loss'],'r',label='loss')
# # plt.plot(hist.history['val_loss'],'b',label='val_loss')
# plt.legend()
# plt.show()

# %% [markdown]
# ## **Predict**

# %%
def get_model_best_epoch(model, model_type, train_data = 'ntb'):
    current_dir = os.getcwd()
    if model_type:
        checkpoint_path = current_dir + "/checkpoints_best_only_{}_{}/checkpoint".format(model_type, train_data)
    
    model.load_weights(checkpoint_path)
    
    return model

# %%
max_x = np.max(X_train_merged_ntb_tb[:,0])
max_y = np.max(X_train_merged_ntb_tb[:,1])

min_x = np.min(X_train_merged_ntb_tb[:,0])
min_y = np.min(X_train_merged_ntb_tb[:,1])

# %%
def plot_data(x, y, labels, colours):
    
    sns.set(style = "darkgrid")

    fig = plt.figure(figsize=(20, 10))
    
    ax = fig.add_subplot(121, projection='3d')

    for c in np.unique(y):
        inx = np.where(y == c)
        ax.scatter(x[inx, 0], x[inx, 1], x[inx, 2], label=labels[c], c=colours[c])
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('Elevation')
        plt.xlim([min_x, max_x])
        plt.ylim([min_y, max_y])
        ax.set_zlim(80, 140)
        
    ax = fig.add_subplot(122, projection='3d')
    for c in np.unique(y):
        inx = np.where(y == c)
        ax.scatter(x[inx, 0], x[inx, 1], x[inx, 2], label=labels[c], c=colours[c])
        ax.set_xlabel('X')
        ax.set_ylabel('Y')
        ax.set_zlabel('Elevation')
        ax.view_init(90, 0)   
        plt.xlim([min_x, max_x])
        plt.ylim([min_y, max_y])
        ax.set_zlim(80, 140)
    plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=5)

# %%
labels = {}
for k, v in assign_num_list.items():
    labels[v] = k

# %%
label_colours = ['black', 'magenta', 'blue']

# %% [markdown]
# # **Ground truth**

# %% [markdown]
# ### **NTB**

# %%
plot_data(X_train_ntb, y_train_ntb, labels, label_colours)
plt.show()

# %% [markdown]
# ### **TB**

# %%
plot_data(X_train_tb, y_train_tb, labels, label_colours)
plt.show()

# %% [markdown]
# ### **Merged NTB and TB**

# %%
plot_data(X_train_merged_ntb_tb, y_train_merged_ntb_tb, labels, label_colours)
plt.show()

# %% [markdown]
# # **Deterministic model results**

# %% [markdown]
# ## **Train on NTB results**

# %%
model_best = get_model_best_epoch(model, model_type = 'deterministic', train_data ='ntb')

# %%
y_predict = np.around(model_best.predict(normalized_X_train_ntb)).astype(int)
y_predict[y_predict < 0] = 0
y_predict[y_predict > 2] = 2

# %%
plot_data(X_train_ntb, y_predict, labels, label_colours)
plt.show()

# %% [markdown]
# ## **Train on TB results**

# %%
model_best = get_model_best_epoch(model, model_type = 'deterministic', train_data ='tb')

# %%
y_predict = np.around(model_best.predict(normalized_X_train_tb)).astype(int)
y_predict[y_predict < 0] = 0
y_predict[y_predict > 2] = 2

# %%
plot_data(X_train_tb, y_predict, labels, label_colours)
plt.show()

# %% [markdown]
# ## **Train on merged NTB and TB results**

# %%
model_best = get_model_best_epoch(model, model_type = 'deterministic', train_data ='merged_ntb_tb')

# %%
y_predict = np.around(model_best.predict(normalized_X_merged_ntb_tb)).astype(int)
y_predict[y_predict < 0] = 0
y_predict[y_predict > 2] = 2

# %%
plot_data(X_train_merged_ntb_tb, y_predict, labels, label_colours)
plt.show()

# %% [markdown]
# # **Probabilistic model results**

# %%
# model_best = get_model_best_epoch(model_prob, model_type = 'probabilistic')
# # model_best = get_model_best_epoch(model, model_type = 'deterministic')

# %%
# y_predict = np.around(model_best.predict(normalized_X_train_ntb)).astype(int)
# y_predict[y_predict < 0] = 0
# y_predict[y_predict > 8] = 8

# %%
# plot_data(X_train_ntb, y_predict, labels, label_colours)
# plt.show()
